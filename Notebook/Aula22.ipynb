# %% [markdown]
# <strong><b><font size="5">Data Science Academy</font></b></strong>

# %% [markdown]
# <strong><b><font size="5">Análise Estatística e Modelagem Preditiva de Séries Temporais - Em Python</font></b></strong>

# %% [markdown]
# <strong><b><font size="5">Aula 22</font></b></strong>
#
# <strong><b><font size="4">Aplicando Inteligência Artificial Para Prever a Média Mensal de Vendas</font></b></strong>

# %% [markdown]
# Todas as aulas deste curso podem ser encontradas na timeline da Comunidade em nosso portal: www.datascienceacademy.com.br/social

# %% [markdown]
# O que acha de trazer Inteligência Artificial para nossa conversa?
#
# De todos os modelos que criamos até aqui no curso, nenhum deles pode ser considerado Inteligência Artificial, mas a partir de agora usaremos Deep Learning, atualmente a principalmente técnica de IA e o estado de arte para a solução de diversos problemas, incluindo previsões de séries temporais.
#
# **Deep Learning - Modelo LSTM**
#
# Os problemas de previsão de séries temporais são um tipo difícil de problema de modelagem preditiva. As séries temporais adicionam a complexidade de uma dependência de sequência entre as variáveis de entrada.
#
# Um tipo poderoso de rede neural projetada para lidar com a dependência de sequência é chamado de Rede Neural Recorrente. A rede Long Short-Term Memory ou LSTM é um tipo de rede neural recorrente usada em aprendizado profundo que apresenta bons resultados, quando devidamente treinada.
#
# Esta e as próximas aulas consideram que você já tem alguma noção sobre o que é Deep Learning e a definição de Deep Learning.
#
# Esse conhecimento pode ser obtido no material gratuito fornecido pela DSA, o <a href="http://www.deeplearningbook.com.br/">Deep Learning Book</a>. Lá você encontra alguns capítulos inteiros dedicados às LSTMs. Recomendamos a leitura antes de prosseguir nesta aula.
#
# **No Google Colab, altere seu Runtime para executar o treinamento usando GPU**.
#
# Vamos ao trabalho.

# %% [markdown]
# ### Carregando os Pacotes Usados Neste Jupyter Notebook

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook, se necessário.

# %%
# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
# É preciso atualizar o Statsmodels
# !pip install -q -U statsmodels

# %%
# As novas versões do Pandas e Matplotlib trazem diversas mensagens de aviso ao desenvolvedor. Vamos desativar isso.
import sys
import warnings
import matplotlib.cbook
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=matplotlib.cbook.mplDeprecation)

# Imports para manipulação de dados
import numpy as np
import pandas as pd
import itertools
from pandas import Series
from pandas.tseries.offsets import DateOffset

# Imports para visualização de dados
import matplotlib.pyplot as plt
import matplotlib as m
import seaborn as sns

# Imports para modelagem preditiva
import sklearn
import keras
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers import LSTM
from keras.layers import Dropout
import statsmodels
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.stats as sms
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# Imports para formatação dos gráficos
m.rcParams['axes.labelsize'] = 14
m.rcParams['xtick.labelsize'] = 12
m.rcParams['ytick.labelsize'] = 12
m.rcParams['text.color'] = 'k'
from matplotlib.pylab import rcParams 
rcParams['figure.figsize'] = 15,7
matplotlib.style.use('ggplot')
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# pandas          1.0.3
# matplotlib      3.2.1
# seaborn         0.10.0
# numpy           1.18.3
# statsmodels     0.11.1
# sklearn         0.22.2.post1
# keras           2.3.1
# statsmodels.api 0.11.1
# Data Science Academy

# %% [markdown]
# ## Definição do Problema de Negócio
#
# A HappyMoonVC é uma Venture Capital (VC).
#
# Além do investimento no GoInRail (descrito nas aulas anteriores), a HappyMoonVC está analisando um outro negócio. Uma rede de varejo que poderá fornecer produtos para os clientes do GoInRail (drone elétrico para transporte de passageiros).
#
# Um monitor touch-screen dentro do GoInRail permitiria que o cliente fizesse a compra de produtos enquanto faz a viagem, com a opção de pegar o produto na estação que for descer ou então receber direto na residência (se acha que isso é futurista demais, saiba que já existe no metrô do Japão).
#
# Para decidir se o investimento vale a pena, a HappyMoonVC precisa prever o volume de vendas.
#
# Esse é nosso trabalho.

# %% [markdown]
# ## Conjunto de Dados

# %% [markdown]
# Usaremos conjuntos de dados que está disponível publicamente no site do Tableau e que representa as vendas históricas da empresa na qual a HappyMoonVC pretende investir. Aqui o link do dataset (que está sendo fornecido para você):
#
# https://community.tableau.com/docs/DOC-1236
#
# De todos os dados disponíveis, nosso interesse é na categoria de produtos de tecnologia.

# %%
# Carrega os dados
dados = pd.read_csv('https://raw.githubusercontent.com/dsacademybr/Datasets/master/dataset6.csv')

# %%
# Shape
dados.shape
# Out:
# (9994, 21)

# %%
# Colunas
dados.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### Análise Exploratória

# %%
# Visualizando os dados
dados.head(3)
# Out:
#    Row ID        Order ID  Order Date  ... Quantity Discount    Profit
# 0       1  CA-2016-152156  2016-11-08  ...        2      0.0   41.9136
# 1       2  CA-2016-152156  2016-11-08  ...        3      0.0  219.5820
# 2       3  CA-2016-138688  2016-06-12  ...        2      0.0    6.8714
#
# [3 rows x 21 columns]

# %%
# Resumo estatístico
dados.describe()
# Out:
#             Row ID   Postal Code  ...     Discount       Profit
# count  9994.000000   9994.000000  ...  9994.000000  9994.000000
# mean   4997.500000  55190.379428  ...     0.156203    28.656896
# std    2885.163629  32063.693350  ...     0.206452   234.260108
# min       1.000000   1040.000000  ...     0.000000 -6599.978000
# 25%    2499.250000  23223.000000  ...     0.000000     1.728750
# 50%    4997.500000  56430.500000  ...     0.200000     8.666500
# 75%    7495.750000  90008.000000  ...     0.200000    29.364000
# max    9994.000000  99301.000000  ...     0.800000  8399.976000
#
# [8 rows x 6 columns]

# %%
# Checando valores missing - não temos valores missing no dataset
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
# Ajustando o nome das colunas para que todas fiquem com letras minúsculas
dados.columns = map(str.lower, dados.columns)

# %%
# Vamos substituir os espaços e traços nos nomes das colunas por '_'
dados.columns = dados.columns.str.replace(" ", "_")
dados.columns = dados.columns.str.replace("-", "_")

# %%
# Conferindo
dados.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %% [markdown]
# Vamos separar os dados por categoria (Móveis, Tecnologia, Material de escritório).

# %%
# Separando os dados por categoria
df_tecnologia = dados.loc[dados['category'] == 'Technology']
df_moveis = dados.loc[dados['category'] == 'Furniture']
df_office = dados.loc[dados['category'] == 'Office Supplies']

# %% [markdown]
# Agora vamos preparar as séries temporais.

# %%
# Agregando as vendas pela data do pedido
ts_tecnologia = df_tecnologia.groupby('order_date')['sales'].sum().reset_index()
ts_moveis = df_moveis.groupby('order_date')['sales'].sum().reset_index()
ts_office = df_office.groupby('order_date')['sales'].sum().reset_index()

# %% [markdown]
# Acesse o <a href="http://datascienceacademy.com.br/blog/">Blog da DSA</a> e fique por dentro das novidades em Data Science, Big Data, IA, RPA, Blockchain e mercado de trabalho.

# %%
# Como está ficando o nosso dataset de interesse?
ts_tecnologia
# Out:
#      order_date     sales
# 0    2014-01-06  1147.940
# 1    2014-01-09    31.200
# 2    2014-01-13   646.740
# 3    2014-01-15   149.950
# 4    2014-01-16   124.200
# ..          ...       ...
# 819  2017-12-25   401.208
# 820  2017-12-27   164.388
# 821  2017-12-28    14.850
# 822  2017-12-29   302.376
# 823  2017-12-30    90.930
#
# [824 rows x 2 columns]

# %% [markdown]
# Vamos mover a data para o índice e assim criar a série temporal.

# %%
# Colocando a data como índice
ts_tecnologia = ts_tecnologia.set_index('order_date')

# %%
# Visualizando a série
ts_tecnologia
# Out:
#                sales
# order_date
# 2014-01-06  1147.940
# 2014-01-09    31.200
# 2014-01-13   646.740
# 2014-01-15   149.950
# 2014-01-16   124.200
# ...              ...
# 2017-12-25   401.208
# 2017-12-27   164.388
# 2017-12-28    14.850
# 2017-12-29   302.376
# 2017-12-30    90.930
#
# [824 rows x 1 columns]

# %% [markdown]
# Agora podemos conferir a performance de vendas ao longo do tempo.

# %%
# Venda de Produtos de Tecnologia
vendas_tecnologia = ts_tecnologia[['sales']]
ax = vendas_tecnologia.plot(color = 'b', figsize = (18,6))
plt.xlabel("Data")
plt.ylabel('Vendas')
plt.title("Venda de Produtos de Tecnologia")
plt.show()

# %% [markdown]
# Vamos ajustar o indice do tipo Index para o tipo DateTimeIndex (o que caracteriza uma série temporal), pois faremos uma agregação pela média para analisar a venda média ao longo do tempo.

# %%
# Conferindo o tipo do índice
type(vendas_tecnologia.index)
# Out:
# pandas.core.indexes.base.Index

# %%
# Alterando o tipo do índice
vendas_tecnologia.index = pd.to_datetime(vendas_tecnologia.index)

# %%
# Conferindo o tipo do índice
type(vendas_tecnologia.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# Reamostrando os dados para frequência mensal
# Usando o valor médio das vendas diárias - definimos o mês como índice
media_vendas_tecnologia = vendas_tecnologia['sales'].resample('MS').mean()

# %%
# Verificando o tipo resultante
type(media_vendas_tecnologia)
# Out:
# pandas.core.series.Series

# %%
# Checando os dados
media_vendas_tecnologia
# Out:
# order_date
# 2014-01-01     449.041429
# 2014-02-01     229.787143
# 2014-03-01    2031.948375
# 2014-04-01     613.028933
# 2014-05-01     564.698588
# 2014-06-01     766.905909
# 2014-07-01     533.608933
# 2014-08-01     708.435385
# 2014-09-01    2035.838133
# 2014-10-01     596.900900
# 2014-11-01    1208.056320
# 2014-12-01    1160.732889
# 2015-01-01     925.070800
# 2015-02-01     431.121250
# 2015-03-01     574.662333
# 2015-04-01     697.559500
# 2015-05-01     831.642857
# 2015-06-01     429.024400
# 2015-07-01     691.397733
# 2015-08-01    1108.902286
# 2015-09-01     950.856400
# 2015-10-01     594.716111
# 2015-11-01    1037.982652
# 2015-12-01    1619.637636
# 2016-01-01     374.671067
# 2016-02-01    1225.891400
# 2016-03-01    1135.150105
# 2016-04-01     875.911882
# 2016-05-01    1601.816167
# 2016-06-01    1023.259500
# 2016-07-01     829.312500
# 2016-08-01     483.620100
# 2016-09-01    1144.170300
# 2016-10-01    1970.835875
# 2016-11-01    1085.642360
# 2016-12-01     970.554870
# 2017-01-01    1195.218071
# 2017-02-01     430.501714
# 2017-03-01    1392.859250
# 2017-04-01     825.559133
# 2017-05-01     678.329400
# 2017-06-01     853.055000
# 2017-07-01    1054.996636
# 2017-08-01     978.842333
# 2017-09-01    1077.704120
# 2017-10-01    1493.439227
# 2017-11-01    1996.750920
# 2017-12-01     955.865652
# Freq: MS, Name: sales, dtype: float64

# %%
# Venda Média de Produtos de Tecnologia
media_vendas_tecnologia.plot(figsize = (18, 6), color = 'blue')
plt.xlabel("Data de Compra")
plt.ylabel('Vendas')
plt.title("Venda Média de Produtos de Tecnologia")
plt.show()

# %% [markdown]
# Agora, vamos decompor uma das séries para avaliar seus componentes.

# %%
# Decomposição da série temporal de venda média de produtos de tecnologia
decomposition = seasonal_decompose(media_vendas_tecnologia, period = 12)
rcParams['figure.figsize'] = 18, 12

# Componentes
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot
plt.subplot(411)
plt.plot(media_vendas_tecnologia, label = 'Série Original')
plt.legend(loc = 'best')
plt.subplot(412)
plt.plot(trend, label = 'Tendência')
plt.legend(loc = 'best')
plt.subplot(413)
plt.plot(seasonal, label = 'Sazonalidade')
plt.legend(loc = 'best')
plt.subplot(414)
plt.plot(residual, label = 'Resíduos')
plt.legend(loc = 'best')
plt.tight_layout()

# %% [markdown]
# Vamos testar a estacionaridade.

# %%
# Função para testar a estacionaridade
def testa_estacionaridade(serie):
    
    # Calcula estatísticas móveis
    rolmean = serie.rolling(window = 12).mean()
    rolstd = serie.rolling(window = 12).std()

    # Plot das estatísticas móveis
    plt.figure(figsize = (20, 6))
    orig = plt.plot(serie, color = 'blue', label = 'Original')
    mean = plt.plot(rolmean, color = 'red', label = 'Média Móvel')
    std = plt.plot(rolstd, color = 'black', label = 'Desvio Padrão')
    plt.legend(loc = 'best')
    plt.title('Estatísticas Móveis - Média e Desvio Padrão')
    plt.show()
    
    # Teste Dickey-Fuller:
    # Print
    print('\nResultado do Teste Dickey-Fuller:\n')

    # Teste
    dfteste = adfuller(serie, autolag = 'AIC')

    # Formatando a saída
    dfsaida = pd.Series(dfteste[0:4], index = ['Estatística do Teste',
                                               'Valor-p',
                                               'Número de Lags Consideradas',
                                               'Número de Observações Usadas'])

    # Loop por cada item da saída do teste
    for key, value in dfteste[4].items():
        dfsaida['Valor Crítico (%s)'%key] = value

    # Print
    print (dfsaida)
    
    # Testa o valor-p
    print ('\nConclusão:')
    if dfsaida[1] > 0.05:
        print('\nO valor-p é maior que 0.05 e, portanto, não temos evidências para rejeitar a hipótese nula.')
        print('Essa série provavelmente não é estacionária.')
    else:
        print('\nO valor-p é menor que 0.05 e, portanto, temos evidências para rejeitar a hipótese nula.')
        print('Essa série provavelmente é estacionária.')

# %%
# Verifica se a série é estacionária
testa_estacionaridade(media_vendas_tecnologia)
# Out:
# Resultado do Teste Dickey-Fuller:
#
# Estatística do Teste           -7.187969e+00
# Valor-p                         2.547334e-10
# Número de Lags Consideradas     0.000000e+00
# Número de Observações Usadas    4.700000e+01
# Valor Crítico (1%)             -3.577848e+00
# Valor Crítico (5%)             -2.925338e+00
# Valor Crítico (10%)            -2.600774e+00
# dtype: float64
#
# Conclusão:
#
# O valor-p é menor que 0.05 e, portanto, temos evidências para rejeitar a hipótese nula.
# Essa série provavelmente é estacionária.

# %% [markdown]
# ### Dividindo os Dados em Treino e Teste

# %% [markdown]
# Para a preparação dos dados, vamos alternar entre objetos NumPy e Pandas, usando o que cada um oferece de melhor. Fique atento a cada passo.

# %%
# Série Original
X = media_vendas_tecnologia

# %%
# Os primeiros 36 registros da série serão usados como dados de treino
X[:-12]
# Out:
# order_date
# 2014-01-01     449.041429
# 2014-02-01     229.787143
# 2014-03-01    2031.948375
# 2014-04-01     613.028933
# 2014-05-01     564.698588
# 2014-06-01     766.905909
# 2014-07-01     533.608933
# 2014-08-01     708.435385
# 2014-09-01    2035.838133
# 2014-10-01     596.900900
# 2014-11-01    1208.056320
# 2014-12-01    1160.732889
# 2015-01-01     925.070800
# 2015-02-01     431.121250
# 2015-03-01     574.662333
# 2015-04-01     697.559500
# 2015-05-01     831.642857
# 2015-06-01     429.024400
# 2015-07-01     691.397733
# 2015-08-01    1108.902286
# 2015-09-01     950.856400
# 2015-10-01     594.716111
# 2015-11-01    1037.982652
# 2015-12-01    1619.637636
# 2016-01-01     374.671067
# 2016-02-01    1225.891400
# 2016-03-01    1135.150105
# 2016-04-01     875.911882
# 2016-05-01    1601.816167
# 2016-06-01    1023.259500
# 2016-07-01     829.312500
# 2016-08-01     483.620100
# 2016-09-01    1144.170300
# 2016-10-01    1970.835875
# 2016-11-01    1085.642360
# 2016-12-01     970.554870
# Freq: MS, Name: sales, dtype: float64

# %%
# Os últimos 12 registros da série serão usados como dados de teste
X[-12:]
# Out:
# order_date
# 2017-01-01    1195.218071
# 2017-02-01     430.501714
# 2017-03-01    1392.859250
# 2017-04-01     825.559133
# 2017-05-01     678.329400
# 2017-06-01     853.055000
# 2017-07-01    1054.996636
# 2017-08-01     978.842333
# 2017-09-01    1077.704120
# 2017-10-01    1493.439227
# 2017-11-01    1996.750920
# 2017-12-01     955.865652
# Freq: MS, Name: sales, dtype: float64

# %%
# Divisão em treino e teste
treino, teste = np.array(X[:-12]), np.array(X[-12:])

# %%
# Ajusta o shape, pois agora não temos um objeto pd.Series, 
# mas sim um array NumPy, que é necessário para treinar o modelo LSTM
trainset = treino.reshape(-1,1)
testset = teste.reshape(-1,1)

# %%
len(trainset)
# Out:
# 36

# %%
trainset
# Out:
# array([[ 449.04142857],
#        [ 229.78714286],
#        [2031.948375  ],
#        [ 613.02893333],
#        [ 564.69858824],
#        [ 766.90590909],
#        [ 533.60893333],
#        [ 708.43538462],
#        [2035.83813333],
#        [ 596.9009    ],
#        [1208.05632   ],
#        [1160.73288889],
#        [ 925.0708    ],
#        [ 431.12125   ],
#        [ 574.66233333],
#        [ 697.5595    ],
#        [ 831.64285714],
#        [ 429.0244    ],
#        [ 691.39773333],
#        [1108.90228571],
#        [ 950.8564    ],
#        [ 594.71611111],
#        [1037.98265217],
#        [1619.63763636],
#        [ 374.67106667],
#        [1225.8914    ],
#        [1135.15010526],
#        [ 875.91188235],
#        [1601.81616667],
#        [1023.2595    ],
#        [ 829.3125    ],
#        [ 483.6201    ],
#        [1144.1703    ],
#        [1970.835875  ],
#        [1085.64236   ],
#        [ 970.55486957]])

# %%
len(testset)
# Out:
# 12

# %%
testset
# Out:
# array([[1195.21807143],
#        [ 430.50171429],
#        [1392.85925   ],
#        [ 825.55913333],
#        [ 678.3294    ],
#        [ 853.055     ],
#        [1054.99663636],
#        [ 978.84233333],
#        [1077.70412   ],
#        [1493.43922727],
#        [1996.75092   ],
#        [ 955.86565217]])

# %% [markdown]
# ### Função Para o Cálculo da Acurácia

# %%
# Função
def performance(y_true, y_pred): 
    mse = ((y_pred - y_true) ** 2).mean()
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return( print('MSE das previsões é {}'.format(round(mse, 2))+
                  '\nRMSE das previsões é {}'.format(round(np.sqrt(mse), 2))+
                  '\nMAPE das previsões é {}'.format(round(mape, 2))))

# %% [markdown]
# Acesse o <a href="http://datascienceacademy.com.br/blog/">Blog da DSA</a> e fique por dentro das novidades em Data Science, Big Data, IA, RPA, Blockchain e mercado de trabalho.

# %% [markdown]
# ## Modelo LSTM

# %% [markdown]
# A rede Long Short-Term Memory, ou LSTM, é uma rede neural recorrente treinada usando Backpropagation Through Time e supera o problema da dissipação do gradiente (isso é explicado no Deep Learning Book).
#
# Como tal, o modelo pode ser usado para criar grandes redes recorrentes que, por sua vez, podem ser usadas para resolver problemas de sequência difíceis no aprendizado de máquina e obter resultados de última geração.
#
# Em vez de neurônios, as redes LSTM possuem blocos de memória conectados através de camadas.
#
# Um bloco possui componentes que o tornam mais inteligente que um neurônio clássico e uma memória para sequências recentes. Um bloco contém portas que gerenciam o estado e a saída do bloco. Um bloco opera sobre uma sequência de entrada e cada porta dentro de um bloco usa as unidades de ativação sigmóide para controlar se são acionadas ou não, condicionando a mudança de estado e a adição de informações que fluem através do bloco.
#
# Existem três tipos de portas dentro de uma unidade:
#
# - Forget Gate: decide condicionalmente quais informações jogar fora do bloco.
# - Input Gate: decide condicionalmente quais valores da entrada atualizar o estado da memória.
# - Output Gate: decide condicionalmente o que enviar com base na entrada e na memória do bloco.
#
# Cada unidade é como uma máquina de mini estado onde os portões das unidades têm pesos que são aprendidos durante o procedimento de treinamento.
#
# Esse modelo é estudado em detalhes no curso <a href="https://www.datascienceacademy.com.br/course?courseid=deep-learning-ii">Deep Learning II</a>.

# %% [markdown]
# ### Preparando os Dados Para Treinamento

# %% [markdown]
# Como regra geral, sempre que você usa uma rede neural, você deve normalizar ou dimensionar seus dados. Usaremos a classe MinMaxScaler da biblioteca sklearn.preprocessing para dimensionar nossos dados entre 0 e 1. O parâmetro feature_range é usado para especificar o intervalo dos dados dimensionados e se não for especificado o intevalo será entre 0 e 1.

# %%
# Cria o scaler
scaler = MinMaxScaler()

# %%
# Treina o scaler nos dados de treino (nunca no dataset completo ou nos dados de teste)
scaler.fit(trainset)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
# Aplica o mesmo scaler aos dados de treino 
# (Não precisamos aplicar aos dados de teste, pois vamos converter a saída das previsões antes de avaliar o modelo)
trainset = scaler.transform(trainset)

# %%
trainset.shape
# Out:
# (36, 1)

# %%
trainset
# Out:
# array([[0.12139983],
#        [0.        ],
#        [0.99784626],
#        [0.21219877],
#        [0.18543853],
#        [0.29739956],
#        [0.16822437],
#        [0.26502477],
#        [1.        ],
#        [0.20326877],
#        [0.54166199],
#        [0.51545928],
#        [0.38497454],
#        [0.11147753],
#        [0.1909554 ],
#        [0.25900285],
#        [0.33324403],
#        [0.11031652],
#        [0.25559112],
#        [0.48676098],
#        [0.39925188],
#        [0.20205906],
#        [0.44749318],
#        [0.76955219],
#        [0.08022139],
#        [0.55153717],
#        [0.50129424],
#        [0.35775554],
#        [0.75968454],
#        [0.43934106],
#        [0.33195373],
#        [0.14054584],
#        [0.50628867],
#        [0.96400863],
#        [0.47388209],
#        [0.41015881]])

# %% [markdown]
# Aqui definimos os hiperparâmetros.

# %%
# Número de repetições
n_rep = 20

# Número de epochs
num_epochs = 200

# Número de inputs (usaremos 12 séries para prever as 12 séries seguintes)
n_input = 12

# Comprimento das sequências de saída (em número de timesteps)
n_output = 12

# Aqui estamos indicando que nossa série é univariada, logo, apenas 1 recurso
n_features = 1

# Número de amostras de séries temporais em cada lote
size_batch = 10

# %% [markdown]
# O TimeseriesGenerator do Keras transforma automaticamente um conjunto de dados univariado de séries temporais em um dataset para problema de aprendizado supervisionado.
#
# https://keras.io/preprocessing/sequence/

# %%
# Generator
generator = TimeseriesGenerator(trainset, 
                                trainset, 
                                length = n_output,
                                batch_size = size_batch)

# %% [markdown]
# Podemos agora criar o modelo.
#
# Para começar a aplicação de Deep Learning ao nosso problema criaremos um modelo básico de LSTM que chamarei de LSTM Padrão.
#
# Aqui está a principal diferença dos modelos de Deep Learning para outros métodos de previsão de séries temporais. Temos que criar o modelo com cada camada da rede neural.
#
# Como trabalharemos com batches de dados da série que serão passados pela rede várias vezes, vamos criar o modelo e gerar os batches de dados a cada passada de um loop. As camadas de rede nada mais são que operações matemáticas.
#
# Nas próximas aulas ensinarei a você como definir os parâmetros da rede (como número de neurônios e dropout). Por agora, leia os comentários em cada linha de código abaixo.

# %%
# Criação e treinamento do modelo LSTM Padrão

# Criamos uma matriz preenchida com zeros que receberá o resultado das previsões do nosso modelo
resultado = np.zeros((n_input, n_rep))

# Loop
# Vamos repetir o processo de treinamento por 20 vezes e armazenar todos os resultados, pois assim usaremos
# diferentes amostras. Ao final, tiramos a média para encontrar as previsões.
for i in range(n_rep):
    
    # O primeiro passo é criar o modelo, ou seja, um objeto da classe Sequential() do Keras
    modelo_lstm = Sequential()
    
    # Podemos adicionar agora a primeira camada da rede, ou camada de entrada.
    # Esta é a camada que recebe os dados.
    modelo_lstm.add(LSTM(50, activation = 'relu', input_shape = (n_input, n_features)))
    
    # A camada de Dropout aplica regularização à rede, removendo alguns neurônios e evitando overfitting
    modelo_lstm.add(Dropout(0.10))
    
    # Adicionamos a primeira camada intermediária ou oculta
    modelo_lstm.add(Dense(100, activation = 'relu'))
    
    # Adicionamos a segunda camada intermediária ou oculta
    modelo_lstm.add(Dense(100, activation = 'relu'))
    
    # Adicionamos a camada de saída e tudo que precisamos é de 1 neurônio pois estamos prevendo apenas 1 valor.
    modelo_lstm.add(Dense(1))
    
    # Com as camadas prontas, podemos definir a função de perda, nesse caso usaremos o MSE (Mean Squared Error)
    # E indicamos o algoritmo de otimização (minimização da função de perda), em nosso caso ADAM
    modelo_lstm.compile(optimizer = 'adam', loss = 'mean_squared_error')
    
    # Aqui fazemos o treinamento gerando batches de dados
    modelo_lstm.fit_generator(generator, epochs = num_epochs)
    
    # Lista para as previsões
    pred_list = []

    # Gera um batch de dados
    batch = trainset[-n_input:].reshape((1, n_input, n_features))

    # Loop para fazer as previsões
    for j in range(n_input):   
        pred_list.append(modelo_lstm.predict(batch)[0]) 
        batch = np.append(batch[:,1:,:], [[pred_list[j]]], axis = 1)

    # Gera o dataframe com as previsões
    df_predict_modelo_lstm = pd.DataFrame(scaler.inverse_transform(pred_list),
                                      index = X[-n_input:].index, columns = ['Prediction'])

    resultado[:,i] = df_predict_modelo_lstm['Prediction']
    
print(resultado)
# Out:
# Streaming output truncated to the last 5000 lines.
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0529
# Epoch 126/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0515
# Epoch 127/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0540
# Epoch 128/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0515
# Epoch 129/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0538
# Epoch 130/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0536
# Epoch 131/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0522
# Epoch 132/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0511
# Epoch 133/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0489
# Epoch 134/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0498
# Epoch 135/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0498
# Epoch 136/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0483
# Epoch 137/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0501
# Epoch 138/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0496
# Epoch 139/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0492
# Epoch 140/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0518
# Epoch 141/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0495
# Epoch 142/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0509
# Epoch 143/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0489
# Epoch 144/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0488
# Epoch 145/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0506
# Epoch 146/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0513
# Epoch 147/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0526
# Epoch 148/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0475
# Epoch 149/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0510
# Epoch 150/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0505
# Epoch 151/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0500
# Epoch 152/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0493
# Epoch 153/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0489
# Epoch 154/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0523
# Epoch 155/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0509
# Epoch 156/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0519
# Epoch 157/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0506
# Epoch 158/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0491
# Epoch 159/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0505
# Epoch 160/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0503
# Epoch 161/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0526
# Epoch 162/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0521
# Epoch 163/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0512
# Epoch 164/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0518
# Epoch 165/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0488
# Epoch 166/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0498
# Epoch 167/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0500
# Epoch 168/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0473
# Epoch 169/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0507
# Epoch 170/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0472
# Epoch 171/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0493
# Epoch 172/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0495
# Epoch 173/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0479
# Epoch 174/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0482
# Epoch 175/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0494
# Epoch 176/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0504
# Epoch 177/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0492
# Epoch 178/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0496
# Epoch 179/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0473
# Epoch 180/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0528
# Epoch 181/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0473
# Epoch 182/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0463
# Epoch 183/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0454
# Epoch 184/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0478
# Epoch 185/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0498
# Epoch 186/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0462
# Epoch 187/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0517
# Epoch 188/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0486
# Epoch 189/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0468
# Epoch 190/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0510
# Epoch 191/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0444
# Epoch 192/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0459
# Epoch 193/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0487
# Epoch 194/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0490
# Epoch 195/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0468
# Epoch 196/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0442
# Epoch 197/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0460
# Epoch 198/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0468
# Epoch 199/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0419
# Epoch 200/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0424
# Epoch 1/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.2113
# Epoch 2/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1729
# Epoch 3/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1298
# Epoch 4/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0901
# Epoch 5/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0645
# Epoch 6/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0595
# Epoch 7/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0632
# Epoch 8/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0617
# Epoch 9/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0642
# Epoch 10/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0536
# Epoch 11/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0518
# Epoch 12/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0559
# Epoch 13/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0534
# Epoch 14/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0505
# Epoch 15/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0526
# Epoch 16/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0505
# Epoch 17/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0587
# Epoch 18/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0499
# Epoch 19/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0511
# Epoch 20/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0482
# Epoch 21/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0519
# Epoch 22/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0507
# Epoch 23/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0535
# Epoch 24/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0521
# Epoch 25/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0502
# Epoch 26/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0528
# Epoch 27/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0528
# Epoch 28/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0533
# Epoch 29/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0476
# Epoch 30/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0522
# Epoch 31/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0537
# Epoch 32/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0523
# Epoch 33/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0509
# Epoch 34/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0561
# Epoch 35/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0546
# Epoch 36/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0553
# Epoch 37/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0535
# Epoch 38/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0496
# Epoch 39/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0497
# Epoch 40/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0508
# Epoch 41/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0513
# Epoch 42/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0507
# Epoch 43/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0548
# Epoch 44/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0546
# Epoch 45/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0565
# Epoch 46/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0560
# Epoch 47/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0517
# Epoch 48/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0555
# Epoch 49/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0516
# Epoch 50/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0515
# Epoch 51/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0527
# Epoch 52/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0545
# Epoch 53/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0504
# Epoch 54/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0533
# Epoch 55/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0520
# Epoch 56/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0571
# Epoch 57/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0515
# Epoch 58/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0531
# Epoch 59/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0543
# Epoch 60/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0475
# Epoch 61/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0535
# Epoch 62/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0559
# Epoch 63/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0536
# Epoch 64/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0553
# Epoch 65/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0492
# Epoch 66/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0556
# Epoch 67/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0526
# Epoch 68/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0515
# Epoch 69/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0490
# Epoch 70/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0518
# Epoch 71/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0522
# Epoch 72/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0535
# Epoch 73/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0490
# Epoch 74/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0524
# Epoch 75/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0514
# Epoch 76/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0543
# Epoch 77/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0489
# Epoch 78/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0500
# Epoch 79/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0561
# Epoch 80/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0500
# Epoch 81/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0569
# Epoch 82/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0522
# Epoch 83/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0489
# Epoch 84/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0540
# Epoch 85/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0517
# Epoch 86/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0504
# Epoch 87/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0500
# Epoch 88/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0538
# Epoch 89/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0532
# Epoch 90/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0504
# Epoch 91/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0521
# Epoch 92/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0518
# Epoch 93/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0485
# Epoch 94/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0548
# Epoch 95/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0502
# Epoch 96/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0531
# Epoch 97/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0517
# Epoch 98/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0534
# Epoch 99/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0497
# Epoch 100/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0499
# Epoch 101/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0485
# Epoch 102/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0528
# Epoch 103/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0502
# Epoch 104/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0545
# Epoch 105/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0519
# Epoch 106/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0493
# Epoch 107/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0516
# Epoch 108/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0502
# Epoch 109/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0522
# Epoch 110/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0492
# Epoch 111/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0515
# Epoch 112/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0495
# Epoch 113/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0485
# Epoch 114/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0500
# Epoch 115/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0522
# Epoch 116/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0517
# Epoch 117/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0502
# Epoch 118/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0492
# Epoch 119/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0501
# Epoch 120/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0505
# Epoch 121/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0501
# Epoch 122/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0511
# Epoch 123/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0508
# Epoch 124/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0488
# Epoch 125/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0501
# Epoch 126/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0518
# Epoch 127/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0489
# Epoch 128/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0508
# Epoch 129/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0499
# Epoch 130/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0528
# Epoch 131/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0523
# Epoch 132/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0499
# Epoch 133/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0533
# Epoch 134/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0479
# Epoch 135/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0472
# Epoch 136/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0462
# Epoch 137/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0497
# Epoch 138/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0502
# Epoch 139/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0493
# Epoch 140/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0500
# Epoch 141/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0514
# Epoch 142/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0463
# Epoch 143/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0501
# Epoch 144/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0472
# Epoch 145/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0549
# Epoch 146/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0466
# Epoch 147/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0483
# Epoch 148/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0444
# Epoch 149/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0451
# Epoch 150/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0467
# Epoch 151/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0486
# Epoch 152/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0478
# Epoch 153/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0485
# Epoch 154/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0454
# Epoch 155/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0476
# Epoch 156/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0462
# Epoch 157/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0461
# Epoch 158/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0450
# Epoch 159/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0436
# Epoch 160/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0463
# Epoch 161/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0512
# Epoch 162/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0453
# Epoch 163/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0441
# Epoch 164/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0447
# Epoch 165/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0455
# Epoch 166/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0435
# Epoch 167/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0445
# Epoch 168/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0430
# Epoch 169/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0460
# Epoch 170/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0434
# Epoch 171/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0494
# Epoch 172/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0457
# Epoch 173/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0408
# Epoch 174/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0474
# Epoch 175/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0413
# Epoch 176/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0439
# Epoch 177/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0424
# Epoch 178/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0387
# Epoch 179/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0415
# Epoch 180/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0430
# Epoch 181/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0409
# Epoch 182/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0454
# Epoch 183/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0392
# Epoch 184/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0426
# Epoch 185/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0418
# Epoch 186/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0473
# Epoch 187/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0390
# Epoch 188/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0450
# Epoch 189/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0424
# Epoch 190/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0398
# Epoch 191/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0440
# Epoch 192/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0411
# Epoch 193/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0391
# Epoch 194/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0428
# Epoch 195/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0450
# Epoch 196/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0408
# Epoch 197/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0453
# Epoch 198/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0361
# Epoch 199/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0435
# Epoch 200/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0408
# Epoch 1/200
# 3/3 [==============================] - 0s 134ms/step - loss: 0.2068
# Epoch 2/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1612
# Epoch 3/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1158
# Epoch 4/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0887
# Epoch 5/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0622
# Epoch 6/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0527
# Epoch 7/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0581
# Epoch 8/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0609
# Epoch 9/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0599
# Epoch 10/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0538
# Epoch 11/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0477
# Epoch 12/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0529
# Epoch 13/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0533
# Epoch 14/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0514
# Epoch 15/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0552
# Epoch 16/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0552
# Epoch 17/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0508
# Epoch 18/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0520
# Epoch 19/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0499
# Epoch 20/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0532
# Epoch 21/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0554
# Epoch 22/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0496
# Epoch 23/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0511
# Epoch 24/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0556
# Epoch 25/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0510
# Epoch 26/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0540
# Epoch 27/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0479
# Epoch 28/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0509
# Epoch 29/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0529
# Epoch 30/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0567
# Epoch 31/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0502
# Epoch 32/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0570
# Epoch 33/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0520
# Epoch 34/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0514
# Epoch 35/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0480
# Epoch 36/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0511
# Epoch 37/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0530
# Epoch 38/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0512
# Epoch 39/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0522
# Epoch 40/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0584
# Epoch 41/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0520
# Epoch 42/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0521
# Epoch 43/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0520
# Epoch 44/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0523
# Epoch 45/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0518
# Epoch 46/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0508
# Epoch 47/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0512
# Epoch 48/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0571
# Epoch 49/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0587
# Epoch 50/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0542
# Epoch 51/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0508
# Epoch 52/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0505
# Epoch 53/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0550
# Epoch 54/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0556
# Epoch 55/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0542
# Epoch 56/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0574
# Epoch 57/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0520
# Epoch 58/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0508
# Epoch 59/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0502
# Epoch 60/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0533
# Epoch 61/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0546
# Epoch 62/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0614
# Epoch 63/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0559
# Epoch 64/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0524
# Epoch 65/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0542
# Epoch 66/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0511
# Epoch 67/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0502
# Epoch 68/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0515
# Epoch 69/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0555
# Epoch 70/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0515
# Epoch 71/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0508
# Epoch 72/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0510
# Epoch 73/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0522
# Epoch 74/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0504
# Epoch 75/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0532
# Epoch 76/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0529
# Epoch 77/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0534
# Epoch 78/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0528
# Epoch 79/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0515
# Epoch 80/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0490
# Epoch 81/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0533
# Epoch 82/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0502
# Epoch 83/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0498
# Epoch 84/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0509
# Epoch 85/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0505
# Epoch 86/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0507
# Epoch 87/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0508
# Epoch 88/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0506
# Epoch 89/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0542
# Epoch 90/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0530
# Epoch 91/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0510
# Epoch 92/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0543
# Epoch 93/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0492
# Epoch 94/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0510
# Epoch 95/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0491
# Epoch 96/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0563
# Epoch 97/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0548
# Epoch 98/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0554
# Epoch 99/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0559
# Epoch 100/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0519
# Epoch 101/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0514
# Epoch 102/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0563
# Epoch 103/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0556
# Epoch 104/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0505
# Epoch 105/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0504
# Epoch 106/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0504
# Epoch 107/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0548
# Epoch 108/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0507
# Epoch 109/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0505
# Epoch 110/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0506
# Epoch 111/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0535
# Epoch 112/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0510
# Epoch 113/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0504
# Epoch 114/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0546
# Epoch 115/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0528
# Epoch 116/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0522
# Epoch 117/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0578
# Epoch 118/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0518
# Epoch 119/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0494
# Epoch 120/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0545
# Epoch 121/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0537
# Epoch 122/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0497
# Epoch 123/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0515
# Epoch 124/200
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0493
# Epoch 125/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0549
# Epoch 126/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0528
# Epoch 127/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0559
# Epoch 128/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0501
# Epoch 129/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0514
# Epoch 130/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0516
# Epoch 131/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0488
# Epoch 132/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0511
# Epoch 133/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0509
# Epoch 134/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0484
# Epoch 135/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0529
# Epoch 136/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0532
# Epoch 137/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0514
# Epoch 138/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0510
# Epoch 139/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0514
# Epoch 140/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0518
# Epoch 141/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0552
# Epoch 142/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0497
# Epoch 143/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0513
# Epoch 144/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0487
# Epoch 145/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0499
# Epoch 146/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0556
# Epoch 147/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0499
# Epoch 148/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0494
# Epoch 149/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0477
# Epoch 150/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0540
# Epoch 151/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0524
# Epoch 152/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0556
# Epoch 153/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0532
# Epoch 154/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0479
# Epoch 155/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0513
# Epoch 156/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0500
# Epoch 157/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0550
# Epoch 158/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0512
# Epoch 159/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0520
# Epoch 160/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0507
# Epoch 161/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0483
# Epoch 162/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0506
# Epoch 163/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0502
# Epoch 164/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0494
# Epoch 165/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0519
# Epoch 166/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0486
# Epoch 167/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0507
# Epoch 168/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0492
# Epoch 169/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0483
# Epoch 170/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0500
# Epoch 171/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0481
# Epoch 172/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0477
# Epoch 173/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0534
# Epoch 174/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0501
# Epoch 175/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0501
# Epoch 176/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0507
# Epoch 177/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0509
# Epoch 178/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0492
# Epoch 179/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0511
# Epoch 180/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0521
# Epoch 181/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0485
# Epoch 182/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0513
# Epoch 183/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0450
# Epoch 184/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0489
# Epoch 185/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0520
# Epoch 186/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0505
# Epoch 187/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0474
# Epoch 188/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0454
# Epoch 189/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0503
# Epoch 190/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0496
# Epoch 191/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0452
# Epoch 192/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0492
# Epoch 193/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0560
# Epoch 194/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0506
# Epoch 195/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0473
# Epoch 196/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0552
# Epoch 197/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0492
# Epoch 198/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0532
# Epoch 199/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0521
# Epoch 200/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0505
# Epoch 1/200
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2094
# Epoch 2/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1682
# Epoch 3/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1313
# Epoch 4/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0992
# Epoch 5/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0682
# Epoch 6/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0553
# Epoch 7/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0626
# Epoch 8/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0658
# Epoch 9/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0686
# Epoch 10/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0519
# Epoch 11/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0550
# Epoch 12/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0496
# Epoch 13/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0600
# Epoch 14/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0553
# Epoch 15/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0500
# Epoch 16/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0584
# Epoch 17/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0509
# Epoch 18/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0507
# Epoch 19/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0520
# Epoch 20/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0527
# Epoch 21/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0530
# Epoch 22/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0549
# Epoch 23/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0521
# Epoch 24/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0531
# Epoch 25/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0567
# Epoch 26/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0564
# Epoch 27/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0513
# Epoch 28/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0482
# Epoch 29/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0525
# Epoch 30/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0572
# Epoch 31/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0523
# Epoch 32/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0524
# Epoch 33/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0500
# Epoch 34/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0575
# Epoch 35/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0520
# Epoch 36/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0506
# Epoch 37/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0524
# Epoch 38/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0525
# Epoch 39/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0523
# Epoch 40/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0524
# Epoch 41/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0538
# Epoch 42/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0529
# Epoch 43/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0492
# Epoch 44/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0524
# Epoch 45/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0511
# Epoch 46/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0494
# Epoch 47/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0552
# Epoch 48/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0533
# Epoch 49/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0484
# Epoch 50/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0516
# Epoch 51/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0510
# Epoch 52/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0502
# Epoch 53/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0545
# Epoch 54/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0518
# Epoch 55/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0517
# Epoch 56/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0518
# Epoch 57/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0536
# Epoch 58/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0517
# Epoch 59/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0522
# Epoch 60/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0540
# Epoch 61/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0514
# Epoch 62/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0473
# Epoch 63/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0497
# Epoch 64/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0557
# Epoch 65/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0512
# Epoch 66/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0526
# Epoch 67/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0531
# Epoch 68/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0494
# Epoch 69/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0496
# Epoch 70/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0524
# Epoch 71/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0509
# Epoch 72/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0521
# Epoch 73/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0496
# Epoch 74/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0507
# Epoch 75/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0528
# Epoch 76/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0505
# Epoch 77/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0508
# Epoch 78/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0519
# Epoch 79/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0511
# Epoch 80/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0547
# Epoch 81/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0498
# Epoch 82/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0537
# Epoch 83/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0531
# Epoch 84/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0498
# Epoch 85/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0526
# Epoch 86/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0518
# Epoch 87/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0522
# Epoch 88/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0511
# Epoch 89/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0537
# Epoch 90/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0491
# Epoch 91/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0559
# Epoch 92/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0506
# Epoch 93/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0505
# Epoch 94/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0509
# Epoch 95/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0509
# Epoch 96/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0512
# Epoch 97/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0507
# Epoch 98/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0545
# Epoch 99/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0501
# Epoch 100/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0502
# Epoch 101/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0518
# Epoch 102/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0499
# Epoch 103/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0502
# Epoch 104/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0521
# Epoch 105/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0524
# Epoch 106/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0499
# Epoch 107/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0473
# Epoch 108/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0505
# Epoch 109/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0484
# Epoch 110/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0551
# Epoch 111/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0493
# Epoch 112/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0537
# Epoch 113/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0534
# Epoch 114/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0504
# Epoch 115/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0563
# Epoch 116/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0503
# Epoch 117/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0516
# Epoch 118/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0565
# Epoch 119/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0518
# Epoch 120/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0520
# ...
# Epoch 46/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0541
# Epoch 47/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0531
# Epoch 48/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0499
# Epoch 49/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0514
# Epoch 50/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0554
# Epoch 51/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0498
# Epoch 52/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0523
# Epoch 53/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0536
# Epoch 54/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0506
# Epoch 55/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0561
# Epoch 56/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0524
# Epoch 57/200
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0517
# Epoch 58/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0524
# Epoch 59/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0544
# Epoch 60/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0532
# Epoch 61/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0507
# Epoch 62/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0542
# Epoch 63/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0505
# Epoch 64/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0535
# Epoch 65/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0507
# Epoch 66/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0520
# Epoch 67/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0497
# Epoch 68/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0519
# Epoch 69/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0537
# Epoch 70/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0525
# Epoch 71/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0520
# Epoch 72/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0519
# Epoch 73/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0564
# Epoch 74/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0540
# Epoch 75/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0518
# Epoch 76/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0528
# Epoch 77/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0517
# Epoch 78/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0506
# Epoch 79/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0558
# Epoch 80/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0527
# Epoch 81/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0499
# Epoch 82/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0514
# Epoch 83/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0492
# Epoch 84/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0534
# Epoch 85/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0523
# Epoch 86/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0519
# Epoch 87/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0505
# Epoch 88/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0499
# Epoch 89/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0520
# Epoch 90/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0518
# Epoch 91/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0521
# Epoch 92/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0503
# Epoch 93/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0506
# Epoch 94/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0499
# Epoch 95/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0487
# Epoch 96/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0485
# Epoch 97/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0508
# Epoch 98/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0482
# Epoch 99/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0510
# Epoch 100/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0487
# Epoch 101/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0498
# Epoch 102/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0513
# Epoch 103/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0509
# Epoch 104/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0500
# Epoch 105/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0495
# Epoch 106/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0492
# Epoch 107/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0481
# Epoch 108/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0534
# Epoch 109/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0549
# Epoch 110/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0514
# Epoch 111/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0551
# Epoch 112/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0498
# Epoch 113/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0523
# Epoch 114/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0531
# Epoch 115/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0492
# Epoch 116/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0488
# Epoch 117/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0569
# Epoch 118/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0512
# Epoch 119/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0524
# Epoch 120/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0498
# Epoch 121/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0534
# Epoch 122/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0521
# Epoch 123/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0501
# Epoch 124/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0471
# Epoch 125/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0486
# Epoch 126/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0551
# Epoch 127/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0472
# Epoch 128/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0540
# Epoch 129/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0524
# Epoch 130/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0499
# Epoch 131/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0488
# Epoch 132/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0520
# Epoch 133/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0483
# Epoch 134/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0518
# Epoch 135/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0497
# Epoch 136/200
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0506
# Epoch 137/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0517
# Epoch 138/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0557
# Epoch 139/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0477
# Epoch 140/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0483
# Epoch 141/200
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0472
# Epoch 142/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0486
# Epoch 143/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0492
# Epoch 144/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0494
# Epoch 145/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0484
# Epoch 146/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0497
# Epoch 147/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0461
# Epoch 148/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0515
# Epoch 149/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0484
# Epoch 150/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0483
# Epoch 151/200
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0452
# Epoch 152/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0464
# Epoch 153/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0515
# Epoch 154/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0502
# Epoch 155/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0471
# Epoch 156/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0456
# Epoch 157/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0455
# Epoch 158/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0515
# Epoch 159/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0464
# Epoch 160/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0465
# Epoch 161/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0483
# Epoch 162/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0462
# Epoch 163/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0487
# Epoch 164/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0496
# Epoch 165/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0460
# Epoch 166/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0487
# Epoch 167/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0406
# Epoch 168/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0464
# Epoch 169/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0475
# Epoch 170/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0453
# Epoch 171/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0489
# Epoch 172/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0455
# Epoch 173/200
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0475
# Epoch 174/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0464
# Epoch 175/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0433
# Epoch 176/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0399
# Epoch 177/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0449
# Epoch 178/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0451
# Epoch 179/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0400
# Epoch 180/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0416
# Epoch 181/200
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0393
# Epoch 182/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0405
# Epoch 183/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0417
# Epoch 184/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0397
# Epoch 185/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0407
# Epoch 186/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0386
# Epoch 187/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0388
# Epoch 188/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0396
# Epoch 189/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0451
# Epoch 190/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0475
# Epoch 191/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0434
# Epoch 192/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0393
# Epoch 193/200
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0395
# Epoch 194/200
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0394
# Epoch 195/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0387
# Epoch 196/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0364
# Epoch 197/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0317
# Epoch 198/200
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0365
# Epoch 199/200
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0391
# Epoch 200/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0321
# [[ 853.89163896  919.77305923  915.60295119  924.32892756  987.8578398
#    957.78436152  939.00358919 1004.69457833 1043.13448523  969.03050927
#    969.67613431 1037.64373892  954.21676509  917.25487935  997.18708132
#   1109.82989362 1039.73842752  941.90381547 1018.79848483  802.45456523]
#  [ 970.64093873  950.6918515  1080.3528986  1058.32763841 1103.97034174
#   1031.89974827 1192.98521513 1043.85788669 1113.0436477  1071.57982579
#   1106.83009199 1045.15850225 1114.6655956   964.35504287 1002.25293691
#   1154.05749667 1145.26536997  995.18863094 1107.50053013  904.72081863]
#  [ 939.60136424  887.41381532 1054.10225259 1042.52847503 1083.01554348
#   1065.4774177  1181.46655386 1036.71569665 1112.05785172 1066.77910975
#   1110.9450299  1043.75771927 1115.73078273  962.01216943  963.86023412
#   1135.05701267 1183.89662301  984.13878119 1117.72912545  867.05959098]
#  [ 934.41418819  875.61865752 1039.0105048  1039.8022634  1073.7731209
#   1049.54509248 1179.22766938 1039.98370583 1089.042059   1064.013983
#   1120.87204647 1044.15989604 1124.46187242  918.52529935  949.89040449
#   1124.71979949 1206.50216529  987.27637358 1115.12740992  846.34436562]
#  [ 918.87488957  835.33515338 1003.09588262 1017.52397416 1068.7801437
#   1015.26372135 1175.0188077  1030.08645422 1012.1474973  1062.08022969
#   1129.26237316 1045.09100631 1132.96237789  874.73372869  932.71737039
#   1080.34358696 1206.76235299  982.76001244 1099.4908504   817.1393997 ]
#  [ 957.65717419  895.82427238 1119.83888492 1075.10447025 1066.17649049
#   1106.1371552  1194.20412507 1066.8868126  1178.44247737 1063.47347723
#   1100.67628149 1045.00736301 1117.44660058  940.64023119  955.43260703
#   1194.96315836 1269.43497105 1001.43308192 1148.81358958  898.61399693]
#  [ 943.75236458  870.87074333 1114.22854054 1082.78716607 1063.89756057
#   1090.17694887 1187.15225256 1075.3878025  1167.96822698 1057.55633312
#   1063.00380452 1045.67236488 1111.30220937  909.43132478  943.94467957
#   1216.77080605 1299.45419422 1002.59999738 1162.28435831  869.60559813]
#  [ 890.56357204  834.69291928 1045.22626731 1037.03955875 1039.6889628
#   1068.92886083 1096.94936451 1069.46942042 1136.20175244 1027.06711429
#   1017.4008775  1046.48732184 1048.81926891  883.47892041  922.14494408
#   1168.641464   1281.57950376  995.55388409 1127.65705703  791.76340204]
#  [ 925.19238041  834.43472309 1110.05186592 1061.43794176 1080.4694825
#   1078.12171103 1228.03229379 1088.87251178 1190.84504481 1068.43302941
#   1108.91783723 1050.39051412 1132.51961744  894.29431057  929.74824874
#   1175.81799408 1310.74044123 1010.31391141 1153.5999883   812.79048663]
#  [ 911.05628686  836.88637587 1076.32628672 1046.4202565  1072.51163577
#   1021.67911898 1220.9341322  1084.21130888 1115.38291489 1064.14434597
#   1099.06235345 1050.58826538 1126.81852493  835.40652469  923.76194013
#   1153.44303602 1255.96893887 1012.4461157  1132.06738388  782.54283222]
#  [ 990.04182328  939.92178158 1270.46258867 1141.96022188 1071.85341579
#   1180.71731663 1261.11165587 1145.25331328 1353.47624405 1067.63637278
#   1061.76691719 1051.7375264  1106.72755629  970.71828455  973.42657262
#   1396.73737413 1415.91730905 1061.31393008 1224.75610328  901.64388647]
#  [ 987.14175847  925.24049952 1304.81845292 1152.77927211 1075.05941914
#   1198.49404647 1279.62761159 1155.2052506  1359.6321537  1070.37038896
#   1064.12513062 1052.57471289 1110.16511269  960.23612195  969.20387803
#   1424.63278963 1463.43617346 1070.12780188 1247.28650654  901.26345481]]

# %% [markdown]
# O mais delicado na criação do modelo é definir o input_shape da primeira camada. É isso que o modelo espera como entrada para cada amostra em termos do número de etapas de tempo e do número de recursos.
#
# Estamos trabalhando com uma série univariada, portanto, o número de recursos é um, para uma variável.
#
# O número de etapas de tempo como entrada é o número que escolhemos para prever as sequências de saída. Em nosso exemplo, estamos usando 12 sequências para prever 12 sequências.
#
# Quase sempre temos várias amostras; portanto, o modelo espera que o componente de entrada dos dados de treinamento tenha as dimensões ou a forma:
#
# [samples, timesteps, features]
#
# Em nosso exemplo, nós temos:
#
# - samples = n_rep (20)
# - timesteps = n_input (12)
# - features = n_features (1)

# %% [markdown]
# Agora calculamos o erro modelo.

# %%
# Vamos criar uma matriz com as mesmas dimensões da matriz de resultado usada no treinamento
resultado_final = np.zeros((resultado.shape[0],1))

# %%
# Loop para gerar as previsões finais
for i in range(resultado.shape[0]):
    resultado_final[i] = np.mean(resultado[i,:])

# %%
# Previsões finais
resultado_final
# Out:
# array([[ 965.1902863 ],
#        [1057.86725043],
#        [1047.66725746],
#        [1041.11554386],
#        [1021.97349063],
#        [1069.81036104],
#        [1063.89236382],
#        [1026.46772182],
#        [1062.25121671],
#        [1041.0829289 ],
#        [1129.35900969],
#        [1138.5710268 ]])

# %%
# Ajustamos o shape
resultado_final = resultado_final.reshape((12,))

# %%
# Previsões finais
resultado_final
# Out:
# array([ 965.1902863 , 1057.86725043, 1047.66725746, 1041.11554386,
#        1021.97349063, 1069.81036104, 1063.89236382, 1026.46772182,
#        1062.25121671, 1041.0829289 , 1129.35900969, 1138.5710268 ])

# %%
# Calculamos e imprimos a performance do modelo
modelo_lstm_performance = performance(testset, resultado_final)
modelo_lstm_performance
# Out:
# MSE das previsões é 156452.09
# RMSE das previsões é 395.54
# MAPE das previsões é 32.5

# %% [markdown]
# Nossa rede não apresentou um resultado magnífico, mas não foi ruim. Está no mesmo nível de um modelo SARIMAX e apenas um pouco abaixo de um modelo Prophet.
#
# A diferença é que ainda temos muitas opções de otimização do Modelo LSTM, conforme veremos nas próximas aulas.
#
# Abaixo o plot das previsões.

# %%
# Plot
plt.figure(figsize = (20, 6))

# Série original
plt.plot(media_vendas_tecnologia.index, 
         media_vendas_tecnologia.values,
         label = 'Valores Observados',
         color = 'Blue')

# Previsões
plt.plot(media_vendas_tecnologia[36:].index, 
         resultado_final,
         label = 'Previsões Com Modelo LSTM Padrão', 
         color = 'Red')

plt.title('Previsões Com Modelo LSTM Padrão')
plt.xlabel('Data')
plt.ylabel('Vendas')
plt.legend()
plt.show()

# %% [markdown]
# Vamos fazer o Forecasting para 12 meses de horizonte de previsão. A função DateOffset() vai nos ajudar a criar as datas.

# %% [markdown]
# Vejamos qual é a última data da nossa série original:

# %%
# Última data da série
media_vendas_tecnologia.index[-1]
# Out:
# Timestamp('2017-12-01 00:00:00', freq='MS')

# %%
# Cria sequência de datas a partir da última data da nossa série original
datas_para_prever_forecasting = [media_vendas_tecnologia.index[-1] + DateOffset(months = x) for x in range(0, 13)]

# %%
# Visualiza as datas criadas
datas_para_prever_forecasting
# Out:
# [Timestamp('2017-12-01 00:00:00'),
#  Timestamp('2018-01-01 00:00:00'),
#  Timestamp('2018-02-01 00:00:00'),
#  Timestamp('2018-03-01 00:00:00'),
#  Timestamp('2018-04-01 00:00:00'),
#  Timestamp('2018-05-01 00:00:00'),
#  Timestamp('2018-06-01 00:00:00'),
#  Timestamp('2018-07-01 00:00:00'),
#  Timestamp('2018-08-01 00:00:00'),
#  Timestamp('2018-09-01 00:00:00'),
#  Timestamp('2018-10-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2018-12-01 00:00:00')]

# %%
# Nossa série original é um objeto do tipo pd.Series
type(media_vendas_tecnologia)
# Out:
# pandas.core.series.Series

# %%
# Objetos do tipo pd.Series dão mais trabalho para manipular. Vamos converter a série original em dataframe.
df_original = pd.DataFrame(media_vendas_tecnologia)

# %%
# Visualiza os dados
df_original.head()
# Out:
#                   sales
# order_date
# 2014-01-01   449.041429
# 2014-02-01   229.787143
# 2014-03-01  2031.948375
# 2014-04-01   613.028933
# 2014-05-01   564.698588

# %%
# Vamos agora criar um novo dataframe 
# O índice (data) será a sequência de datas futuras
# O nome da coluna de dados extraímos da série original
# ATENÇÃO: Não estamos extraindo os dados da série original, somente o nome da coluna
data_futuras = pd.DataFrame(index = datas_para_prever_forecasting[1:], columns = df_original.columns)

# %%
# Visualiza os dados
# Entendeu por que os valores NaN? São datas futuras, e precisamos agora incluir nossas previsões.
data_futuras
# Out:
#            sales
# 2018-01-01   NaN
# 2018-02-01   NaN
# 2018-03-01   NaN
# 2018-04-01   NaN
# 2018-05-01   NaN
# 2018-06-01   NaN
# 2018-07-01   NaN
# 2018-08-01   NaN
# 2018-09-01   NaN
# 2018-10-01   NaN
# 2018-11-01   NaN
# 2018-12-01   NaN

# %%
# Usamos as datas futuras para extrair as previsões do nosso modelo
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index = data_futuras[-n_input:].index, columns = ['Prediction'])

# %%
# Concatenamos a série original com os valores de forecasting de 12 meses além da série
df_forecasting = pd.concat([df_original, df_predict], axis = 1)

# %%
# Visualiza o dataframe
df_forecasting
# Out:
#                   sales  Prediction
# 2014-01-01   449.041429         NaN
# 2014-02-01   229.787143         NaN
# 2014-03-01  2031.948375         NaN
# 2014-04-01   613.028933         NaN
# 2014-05-01   564.698588         NaN
# 2014-06-01   766.905909         NaN
# 2014-07-01   533.608933         NaN
# 2014-08-01   708.435385         NaN
# 2014-09-01  2035.838133         NaN
# 2014-10-01   596.900900         NaN
# 2014-11-01  1208.056320         NaN
# 2014-12-01  1160.732889         NaN
# 2015-01-01   925.070800         NaN
# 2015-02-01   431.121250         NaN
# 2015-03-01   574.662333         NaN
# 2015-04-01   697.559500         NaN
# 2015-05-01   831.642857         NaN
# 2015-06-01   429.024400         NaN
# 2015-07-01   691.397733         NaN
# 2015-08-01  1108.902286         NaN
# 2015-09-01   950.856400         NaN
# 2015-10-01   594.716111         NaN
# 2015-11-01  1037.982652         NaN
# 2015-12-01  1619.637636         NaN
# 2016-01-01   374.671067         NaN
# 2016-02-01  1225.891400         NaN
# 2016-03-01  1135.150105         NaN
# 2016-04-01   875.911882         NaN
# 2016-05-01  1601.816167         NaN
# 2016-06-01  1023.259500         NaN
# 2016-07-01   829.312500         NaN
# 2016-08-01   483.620100         NaN
# 2016-09-01  1144.170300         NaN
# 2016-10-01  1970.835875         NaN
# 2016-11-01  1085.642360         NaN
# 2016-12-01   970.554870         NaN
# 2017-01-01  1195.218071         NaN
# 2017-02-01   430.501714         NaN
# 2017-03-01  1392.859250         NaN
# 2017-04-01   825.559133         NaN
# 2017-05-01   678.329400         NaN
# 2017-06-01   853.055000         NaN
# 2017-07-01  1054.996636         NaN
# 2017-08-01   978.842333         NaN
# 2017-09-01  1077.704120         NaN
# 2017-10-01  1493.439227         NaN
# 2017-11-01  1996.750920         NaN
# 2017-12-01   955.865652         NaN
# 2018-01-01          NaN  802.454565
# 2018-02-01          NaN  904.720819
# 2018-03-01          NaN  867.059591
# 2018-04-01          NaN  846.344366
# 2018-05-01          NaN  817.139400
# 2018-06-01          NaN  898.613997
# 2018-07-01          NaN  869.605598
# 2018-08-01          NaN  791.763402
# 2018-09-01          NaN  812.790487
# 2018-10-01          NaN  782.542832
# 2018-11-01          NaN  901.643886
# 2018-12-01          NaN  901.263455

# %% [markdown]
# ### Previsão x Forecasting

# %% [markdown]
# Esse dataframe acima é para não restar qualquer dúvida do que estamos fazendo.
#
# Nas **previsões** do modelo, usamos os dados de teste, 12 meses que correspondem aos 12 últimos registros da série original (2017-01-01 a 2017-12-01. Fazemos isso para poder calcular a precisão do modelo, comparando as previsões com os valores reais. Esse é o padrão em Machine Learning.
#
# No **forecasting**, criamos 12 meses após a última data da série original. Obviamente, não temos dados históricos para esses meses e o que queremos é exatamente a previsão de vendas. O forecasting significa usar o modelo treinado e prever valores sobre novas datas.
#
# Bingo!

# %% [markdown]
# Vamos colocar o forecasting em um Plot.

# %%
# Plot
plt.figure(figsize = (20, 6))

# Série original
plt.plot(df_forecasting.index, 
         df_forecasting['sales'],
         label = 'Valores Observados',
         color = 'Blue')

# Previsões
plt.plot(df_forecasting.index, 
         df_forecasting['Prediction'],
         label = 'Forecasting Com Modelo LSTM Padrão', 
         color = 'Red')

plt.title('Forecasting Com Modelo LSTM Padrão Em Horizonte de 12 Meses de Previsão')
plt.xlabel('Data')
plt.ylabel('Vendas')
plt.legend()
plt.show()

# %% [markdown]
# E aí está nosso primeiro modelo de Deep Learning para previsão de séries temporais!

# %% [markdown]
# Como estamos até agora:
#
# - Aula 15 --> Modelo ARMA(1,1) - AIC = 550.3, RMSE = 420.2 e MAPE = 29.58
# - Aula 16 --> Modelo ARIMA(6,0,2) - AIC = 559.4, RMSE = 401.5 e MAPE = 26.58
# - Aula 17 --> Modelo SARIMA(0, 0, 0)x(0, 1, 1, 12) - AIC = 176.74, RMSE = 425.89 e MAPE = 34.95
# - Aula 18 --> Modelo SARIMA(1, 1, 0)x(1, 1, 0, 12) - AIC = 146.77, RMSE = 353.57 e MAPE = 30.55
# - Aula 19 --> Modelo SARIMA(1, 1, 0)x(1, 1, 0, 12) com exog  - AIC = 149.66, RMSE = 341.23 e MAPE = 32.54
# - Aula 20 --> Modelo Prophet 1 - RMSE = 347.58 e MAPE = 28.53
# - Aula 21 --> Modelo Prophet 2 - RMSE = 325.52 e MAPE = 26.45
# - Aula 22 --> Modelo LSTM Padrão - RMSE = 395.45 e MAPE = 31.46
#
# Nosso modelo de Deep Learning veio para a briga como um candidato de peso. Nas próximas aulas vamos otimizar o modelo e trabalhar com diferentes arquiteturas LSTM.

# %% [markdown]
# # Fim
